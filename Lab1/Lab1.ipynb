# %% [markdown]
# Задание №1

# %%
import pandas

f = pandas.read_csv("invalid_format_pima.data",sep='\\s+|\\t+|:|\'|,"|,|"')
print(f)
# Out:
#       6    148  72   35      0    33.6   0.627  50    1
# 0     1     85  66   29    0.0  26.600   0.351  31  0.0
# 1     8    183  64    0    0.0  23.300   0.672  32  1.0
# 2     1     89  66   23   94.0  28.100   0.167  21  0.0
# 3     0    137  40   35  168.0  43.100   2.288  33  1.0
# 4     5    116  74    0    0.0  25.600   0.201  30  0.0
# 5     3     78  50   32   88.0  31.000   0.248  26  1.0
# 6    10    115   0    0    0.0  35.300   0.134  29  0.0
# 7     2    197  70   45  543.0  30.500   0.158  53  1.0
# 8     8    125  96    0    0.0   0.000   0.232  54  1.0
# 9     4    110  92    0    0.0  37.600   0.191  30  0.0
# 10   10    168  74    0    0.0  38.000   0.537  34  1.0
# 11   10    139  80    0    0.0  27.100   1.441  57  0.0
# 12    1    189  60   23  846.0  30.100   0.398  59  1.0
# 13    5    166  72   19  175.0  25.800   0.587  51  1.0
# 14    7    100   0    0    0.0  30.000   0.484  32  1.0
# 15    0    118  84   47  230.0  45.800   0.551  31  1.0
# ...

# %% [markdown]
# Задание №2

# %%
import pandas
